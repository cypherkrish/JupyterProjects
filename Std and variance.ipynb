# %%
import numpy as np

# %%
income = np.random.normal(100.0, 2.0, 10000)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(income, 50)
plt.show()

# %%
income.std()
# Out:
# 20.28979612720953

# %%
income.var()
# Out:
# 411.6758268837269
