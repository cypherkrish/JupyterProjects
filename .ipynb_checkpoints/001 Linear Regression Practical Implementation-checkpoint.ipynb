# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset = fetch_california_housing()

# %%
print(dataset.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# An household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surpinsingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
print(dataset.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(dataset.target_names)
# Out:
# ['MedHouseVal']

# %%
print(dataset.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
import pandas as pd

# %%
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df['Price'] = dataset.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df_copy = df.sample(frac = 0.25)

# %%
df.shape
# Out:
# (20640, 9)

# %%
df_copy.shape
# Out:
# (5160, 9)

# %%
sns.pairplot(df_copy)

# %% [markdown]
# ## 1. Divide the dataset into dependent and independent features

# %%
X = df.iloc[:,:-1]
y = df.iloc[:, -1]

# %% [markdown]
# ## 2. Divide the data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 5088   0.9809      19.0  3.187726   1.129964       726.0  2.620939     33.98
# 17096  4.2232      33.0  6.189696   1.086651      1015.0  2.377049     37.46
# 5617   3.5488      42.0  4.821577   1.095436      1044.0  4.331950     33.79
# 20060  1.6469      24.0  4.274194   1.048387      1686.0  4.532258     35.87
# 895    3.9909      14.0  4.608303   1.089350      2738.0  2.471119     37.54
#
#        Longitude
# 5088     -118.28
# 17096    -122.23
# 5617     -118.26
# 20060    -119.26
# 895      -121.96

# %% [markdown]
# ## 3. Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scalar.fit_transform(X_train)

# %%
print(X_train)
# Out:
# [[-1.52169954 -0.75868455 -0.91813082 ... -0.04014979 -0.78315293
#    0.65090402]
#  [ 0.18205382  0.3523991   0.30748451 ... -0.05943619  0.8475975
#   -1.31911678]
#  [-0.17232772  1.06666717 -0.25107784 ...  0.09515433 -0.87218816
#    0.66087881]
#  ...
#  [-0.49518065  0.59048846 -0.59192622 ...  0.01608523 -0.75972261
#    0.60103008]
#  [ 0.96816708 -1.07613702  0.39144665 ...  0.0039722   0.90383028
#   -1.18445713]
#  [-0.68377427  1.86029835 -0.83041358 ... -0.08065717  0.9928655
#   -1.41387727]]

# %%
X_test = scalar.fit_transform(X_test)

# %%
X_test=scalar.transform(X_test)
# Out:
# C:\Users\hellooo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Model training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %% [markdown]
# ## Model FIT

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Coefficients

# %%
regression.coef_
# Out:
# array([ 8.46603472e-01,  1.20333548e-01, -2.98800785e-01,  3.47243173e-01,
#        -8.81413334e-05, -4.17242067e-02, -8.94420371e-01, -8.70401317e-01])

# %% [markdown]
# ## Intercept

# %%
regression.intercept_
# Out:
# 2.0666362048018536

# %% [markdown]
# ## Predicit

# %%
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([0.72563462, 1.76650223, 2.70545812, ..., 1.25803135, 1.66673014,
#        2.25826279])

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_percentage_error
import numpy as np

# %%
mse = mean_squared_error(y_test, y_pred)
print("mse: ", mse)
mae = mean_absolute_error(y_test, y_pred)
print("mae: ",mae)
print("rmse: ", np.sqrt(mse))
# Out:
# mse:  0.5369686543372464
# mae:  0.5295710106684455
# rmse:  0.7327814505957737

# %% [markdown]
# ## Accuracy R2 and adjusted r squared

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)

# %%
score
# Out:
# 0.597049412878395

# %%
#display adjusted R-squared
1 - (1-score)*(len(y)-1)/(len(y)-X.shape[1]-1)
# Out:
# 0.5968931623477871

# %% [markdown]
# ## Ridge Regresion

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("mse: ", mse)
mae = mean_absolute_error(y_test, y_pred)
print("mae: ",mae)
print("rmse: ", np.sqrt(mse))
# Out:
# mse:  1.3326257277946882
# mae:  0.9126511897647483
# rmse:  1.15439409553007

# %% [markdown]
# ## Lasso Regresion

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("mse: ", mse)
mae = mean_absolute_error(y_test, y_pred)
print("mae: ",mae)
print("rmse: ", np.sqrt(mse))
# Out:
# mse:  1.3326257277946882
# mae:  0.9126511897647483
# rmse:  1.15439409553007

# %% [markdown]
# ## ElasticNet

# %%
from sklearn.linear_model import ElasticNet

elastic = ElasticNet()
elastic.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
y_pred = elastic.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print("mse: ", mse)
mae = mean_absolute_error(y_test, y_pred)
print("mae: ",mae)
print("rmse: ", np.sqrt(mse))
# Out:
# mse:  1.3433325704278647
# mae:  0.8435673567435615
# rmse:  1.1590222475983214

# %% [markdown]
# ## Undertand the correlation

# %%
df_copy.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.129339  0.309128  -0.043656   -0.002692 -0.079803
# HouseAge   -0.129339  1.000000 -0.146423  -0.059215   -0.297211 -0.018562
# AveRooms    0.309128 -0.146423  1.000000   0.880064   -0.058996 -0.058754
# AveBedrms  -0.043656 -0.059215  0.880064   1.000000   -0.046022 -0.054071
# Population -0.002692 -0.297211 -0.058996  -0.046022    1.000000  0.217062
# AveOccup   -0.079803 -0.018562 -0.058754  -0.054071    0.217062  1.000000
# Latitude   -0.094719  0.017006  0.089291   0.064289   -0.120210 -0.153596
# Longitude   0.001363 -0.120723 -0.016834   0.005331    0.114923  0.153440
# Price       0.679979  0.100198  0.124810  -0.046590   -0.034735 -0.240763
#
#             Latitude  Longitude     Price
# MedInc     -0.094719   0.001363  0.679979
# HouseAge    0.017006  -0.120723  0.100198
# AveRooms    0.089291  -0.016834  0.124810
# AveBedrms   0.064289   0.005331 -0.046590
# Population -0.120210   0.114923 -0.034735
# AveOccup   -0.153596   0.153440 -0.240763
# Latitude    1.000000  -0.926239 -0.158258
# Longitude  -0.926239   1.000000 -0.030331
# Price      -0.158258  -0.030331  1.000000
